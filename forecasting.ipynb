# %%
# Installation des bibliothèques nécessaires
# pip install requests pandas numpy scikit-learn xgboost matplotlib seaborn

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import xgboost as xgb

# %%
dataset = pd.read_csv('EPL.csv')
dataset.head()
# Out:
#          Date   Season      HomeTeam                AwayTeam  FTH Goals  \
# 0  16/01/2025  2024/25  Ipswich Town  Brighton & Hove Albion          0
# 1  16/01/2025  2024/25    Man United             Southampton          3
# 2  15/01/2025  2024/25       Everton             Aston Villa          0
# 3  15/01/2025  2024/25     Leicester          Crystal Palace          0
# 4  15/01/2025  2024/25     Newcastle                  Wolves          3
#
#    FTA Goals FT Result  HTH Goals  HTA Goals HT Result  ... H Fouls  A Fouls  \
# 0          2         A        0.0        1.0         A  ...    13.0     14.0
# 1          1         H        0.0        1.0         A  ...     7.0     10.0
# 2          1         A        0.0        0.0         D  ...    17.0     10.0
# 3          2         A        0.0        0.0         D  ...     7.0      6.0
# 4          0         H        1.0        0.0         H  ...    10.0     13.0
#
#    H Corners  A Corners  H Yellow  A Yellow  H Red  A Red  Display_Order  \
# 0        1.0        9.0       2.0       2.0    0.0    0.0       20250116
# 1        4.0        4.0       1.0       3.0    0.0    0.0       20250116
# 2        8.0        5.0       2.0       1.0    0.0    0.0       20250115
# 3        4.0        3.0       0.0       0.0    0.0    0.0       20250115
# 4        4.0        2.0       0.0       2.0    0.0    0.0       20250115
#
#            League
# 0  Premier League
# 1  Premier League
# 2  Premier League
# 3  Premier League
# 4  Premier League
#
# [5 rows x 25 columns]

# %%
# Conversion de la colonne 'Date' en format datetime
dataset['Date'] = pd.to_datetime(dataset['Date'], format='%d/%m/%Y')

# %%
# On garde uniquement les matchs à partir de la saison 2018/2019
dataset = dataset[dataset['Date'] >= '01/08/2018']  
dataset = dataset[dataset['Date'] <= '31/05/2024']  # On garde jusqu'à la saison 2023/2024

# %%
dataset['FT Result'].unique()
# Out:
# array(['H', 'A', 'D'], dtype=object)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2440 entries, 209 to 2648
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           2440 non-null   datetime64[ns]
#  1   Season         2440 non-null   object
#  2   HomeTeam       2440 non-null   object
#  3   AwayTeam       2440 non-null   object
#  4   FTH Goals      2440 non-null   int64
#  5   FTA Goals      2440 non-null   int64
#  6   FT Result      2440 non-null   object
#  7   HTH Goals      2440 non-null   float64
#  8   HTA Goals      2440 non-null   float64
#  9   HT Result      2440 non-null   object
#  10  Referee        2440 non-null   object
#  11  H Shots        2440 non-null   float64
#  12  A Shots        2440 non-null   float64
#  13  H SOT          2440 non-null   float64
#  14  A SOT          2440 non-null   float64
#  15  H Fouls        2440 non-null   float64
#  16  A Fouls        2440 non-null   float64
#  17  H Corners      2440 non-null   float64
#  18  A Corners      2440 non-null   float64
#  19  H Yellow       2440 non-null   float64
#  20  A Yellow       2440 non-null   float64
#  21  H Red          2440 non-null   float64
#  22  A Red          2440 non-null   float64
#  23  Display_Order  2440 non-null   int64
#  24  League         2440 non-null   object
# dtypes: datetime64[ns](1), float64(14), int64(3), object(7)
# memory usage: 495.6+ KB

# %%
df_train = dataset[dataset['Date'] < '01/08/2023']
df_test = dataset[dataset['Date'] >= '01/08/2023']
print(f"Taille du dataset d'entraînement: {df_train.shape[0]} matchs")
print(f"Taille du dataset de test: {df_test.shape[0]} matchs")
# Out:
# Taille du dataset d'entraînement: 1856 matchs
# Taille du dataset de test: 584 matchs

# %%
df_train['Day'] = df_train['Date'].dt.day
df_train['Month'] = df_train['Date'].dt.month
df_train['Year'] = df_train['Date'].dt.year
df_train['Weekday'] = df_train['Date'].dt.weekday  # Lundi=0, Dimanche=6

df_test['Day'] = df_test['Date'].dt.day
df_test['Month'] = df_test['Date'].dt.month
df_test['Year'] = df_test['Date'].dt.year
df_test['Weekday'] = df_test['Date'].dt.weekday
# Out:
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Day'] = df_train['Date'].dt.day
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Month'] = df_train['Date'].dt.month
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Year'] = df_train['Date'].dt.year
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Weekday'] = df_train['Date'].dt.weekday  # Lundi=0, Dimanche=6
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Day'] = df_test['Date'].dt.day
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Month'] = df_test['Date'].dt.month
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Year'] = df_test['Date'].dt.year
# C:\Users\Nitropc\AppData\Local\Temp\ipykernel_14376\450495696.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Weekday'] = df_test['Date'].dt.weekday

# %%
df_test.head()
# Out:
#           Date   Season          HomeTeam     AwayTeam  FTH Goals  FTA Goals  \
# 209 2024-05-19  2023/24           Chelsea  Bournemouth          2          1
# 210 2024-05-19  2023/24          Brighton   Man United          0          2
# 211 2024-05-19  2023/24    Crystal Palace  Aston Villa          5          0
# 212 2024-05-19  2023/24           Arsenal      Everton          2          1
# 213 2024-05-19  2023/24  Sheffield United    Tottenham          0          3
#
#     FT Result  HTH Goals  HTA Goals HT Result  ... H Yellow  A Yellow  H Red  \
# 209         H        1.0        0.0         H  ...      2.0       3.0    0.0
# 210         A        0.0        0.0         D  ...      1.0       3.0    0.0
# 211         H        2.0        0.0         H  ...      1.0       4.0    0.0
# 212         H        1.0        1.0         D  ...      4.0       3.0    0.0
# 213         A        0.0        1.0         A  ...      2.0       0.0    0.0
#
#      A Red  Display_Order          League  Day  Month  Year  Weekday
# 209    0.0       20240519  Premier League   19      5  2024        6
# 210    0.0       20240519  Premier League   19      5  2024        6
# 211    0.0       20240519  Premier League   19      5  2024        6
# 212    0.0       20240519  Premier League   19      5  2024        6
# 213    0.0       20240519  Premier League   19      5  2024        6
#
# [5 rows x 29 columns]

# %%
df_train_encoded = pd.get_dummies(df_train, columns=['HomeTeam', 'AwayTeam'])
df_test_encoded = pd.get_dummies(df_test, columns=['HomeTeam', 'AwayTeam'])

# %%
df_train_encoded, df_test_encoded = df_train_encoded.align(df_test_encoded, join='left', axis=1, fill_value=0)

# %%
print(df_train_encoded.shape)
print(df_test_encoded.shape)
# Out:
# (1856, 85)
# (584, 85)

# %%
df_train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1856 entries, 793 to 2648
# Data columns (total 85 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1856 non-null   datetime64[ns]
#  1   Season                     1856 non-null   object
#  2   FTH Goals                  1856 non-null   int64
#  3   FTA Goals                  1856 non-null   int64
#  4   FT Result                  1856 non-null   object
#  5   HTH Goals                  1856 non-null   float64
#  6   HTA Goals                  1856 non-null   float64
#  7   HT Result                  1856 non-null   object
#  8   Referee                    1856 non-null   object
#  9   H Shots                    1856 non-null   float64
#  10  A Shots                    1856 non-null   float64
#  11  H SOT                      1856 non-null   float64
#  12  A SOT                      1856 non-null   float64
#  13  H Fouls                    1856 non-null   float64
#  14  A Fouls                    1856 non-null   float64
#  15  H Corners                  1856 non-null   float64
#  16  A Corners                  1856 non-null   float64
#  17  H Yellow                   1856 non-null   float64
#  18  A Yellow                   1856 non-null   float64
#  19  H Red                      1856 non-null   float64
#  20  A Red                      1856 non-null   float64
#  21  Display_Order              1856 non-null   int64
#  22  League                     1856 non-null   object
#  23  Day                        1856 non-null   int32
#  24  Month                      1856 non-null   int32
#  25  Year                       1856 non-null   int32
#  26  Weekday                    1856 non-null   int32
#  27  HomeTeam_Arsenal           1856 non-null   bool
#  28  HomeTeam_Aston Villa       1856 non-null   bool
#  29  HomeTeam_Bournemouth       1856 non-null   bool
#  30  HomeTeam_Brentford         1856 non-null   bool
#  31  HomeTeam_Brighton          1856 non-null   bool
#  32  HomeTeam_Burnley           1856 non-null   bool
#  33  HomeTeam_Cardiff           1856 non-null   bool
#  34  HomeTeam_Chelsea           1856 non-null   bool
#  35  HomeTeam_Crystal Palace    1856 non-null   bool
#  36  HomeTeam_Everton           1856 non-null   bool
#  37  HomeTeam_Fulham            1856 non-null   bool
#  38  HomeTeam_Huddersfield      1856 non-null   bool
#  39  HomeTeam_Leeds             1856 non-null   bool
#  40  HomeTeam_Leicester         1856 non-null   bool
#  41  HomeTeam_Liverpool         1856 non-null   bool
#  42  HomeTeam_Man City          1856 non-null   bool
#  43  HomeTeam_Man United        1856 non-null   bool
#  44  HomeTeam_Newcastle         1856 non-null   bool
#  45  HomeTeam_Norwich           1856 non-null   bool
#  46  HomeTeam_Nott'm Forest     1856 non-null   bool
#  47  HomeTeam_Sheffield United  1856 non-null   bool
#  48  HomeTeam_Southampton       1856 non-null   bool
#  49  HomeTeam_Stoke             1856 non-null   bool
#  50  HomeTeam_Swansea           1856 non-null   bool
#  51  HomeTeam_Tottenham         1856 non-null   bool
#  52  HomeTeam_Watford           1856 non-null   bool
#  53  HomeTeam_West Brom         1856 non-null   bool
#  54  HomeTeam_West Ham          1856 non-null   bool
#  55  HomeTeam_Wolves            1856 non-null   bool
#  56  AwayTeam_Arsenal           1856 non-null   bool
#  57  AwayTeam_Aston Villa       1856 non-null   bool
#  58  AwayTeam_Bournemouth       1856 non-null   bool
#  59  AwayTeam_Brentford         1856 non-null   bool
#  60  AwayTeam_Brighton          1856 non-null   bool
#  61  AwayTeam_Burnley           1856 non-null   bool
#  62  AwayTeam_Cardiff           1856 non-null   bool
#  63  AwayTeam_Chelsea           1856 non-null   bool
#  64  AwayTeam_Crystal Palace    1856 non-null   bool
#  65  AwayTeam_Everton           1856 non-null   bool
#  66  AwayTeam_Fulham            1856 non-null   bool
#  67  AwayTeam_Huddersfield      1856 non-null   bool
#  68  AwayTeam_Leeds             1856 non-null   bool
#  69  AwayTeam_Leicester         1856 non-null   bool
#  70  AwayTeam_Liverpool         1856 non-null   bool
#  71  AwayTeam_Man City          1856 non-null   bool
#  72  AwayTeam_Man United        1856 non-null   bool
#  73  AwayTeam_Newcastle         1856 non-null   bool
#  74  AwayTeam_Norwich           1856 non-null   bool
#  75  AwayTeam_Nott'm Forest     1856 non-null   bool
#  76  AwayTeam_Sheffield United  1856 non-null   bool
#  77  AwayTeam_Southampton       1856 non-null   bool
#  78  AwayTeam_Stoke             1856 non-null   bool
#  79  AwayTeam_Swansea           1856 non-null   bool
#  80  AwayTeam_Tottenham         1856 non-null   bool
#  81  AwayTeam_Watford           1856 non-null   bool
#  82  AwayTeam_West Brom         1856 non-null   bool
#  83  AwayTeam_West Ham          1856 non-null   bool
#  84  AwayTeam_Wolves            1856 non-null   bool
# dtypes: bool(58), datetime64[ns](1), float64(14), int32(4), int64(3), object(5)
# memory usage: 482.1+ KB

# %%
columns_to_drop = ['FTH Goals', 'FTA Goals', 'FT Result', 
                   'HTH Goals', 'HTA Goals', 'HT Result', 
                   'Display_Order', 'Referee', 'League', 'Date', 'Season']

# %%
# Sélectionner les features (sans les variables cibles)
X_train = df_train_encoded.drop(columns=columns_to_drop)
X_test = df_test_encoded.drop(columns=columns_to_drop)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1856 entries, 793 to 2648
# Data columns (total 74 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   H Shots                    1856 non-null   float64
#  1   A Shots                    1856 non-null   float64
#  2   H SOT                      1856 non-null   float64
#  3   A SOT                      1856 non-null   float64
#  4   H Fouls                    1856 non-null   float64
#  5   A Fouls                    1856 non-null   float64
#  6   H Corners                  1856 non-null   float64
#  7   A Corners                  1856 non-null   float64
#  8   H Yellow                   1856 non-null   float64
#  9   A Yellow                   1856 non-null   float64
#  10  H Red                      1856 non-null   float64
#  11  A Red                      1856 non-null   float64
#  12  Day                        1856 non-null   int32
#  13  Month                      1856 non-null   int32
#  14  Year                       1856 non-null   int32
#  15  Weekday                    1856 non-null   int32
#  16  HomeTeam_Arsenal           1856 non-null   bool
#  17  HomeTeam_Aston Villa       1856 non-null   bool
#  18  HomeTeam_Bournemouth       1856 non-null   bool
#  19  HomeTeam_Brentford         1856 non-null   bool
#  20  HomeTeam_Brighton          1856 non-null   bool
#  21  HomeTeam_Burnley           1856 non-null   bool
#  22  HomeTeam_Cardiff           1856 non-null   bool
#  23  HomeTeam_Chelsea           1856 non-null   bool
#  24  HomeTeam_Crystal Palace    1856 non-null   bool
#  25  HomeTeam_Everton           1856 non-null   bool
#  26  HomeTeam_Fulham            1856 non-null   bool
#  27  HomeTeam_Huddersfield      1856 non-null   bool
#  28  HomeTeam_Leeds             1856 non-null   bool
#  29  HomeTeam_Leicester         1856 non-null   bool
#  30  HomeTeam_Liverpool         1856 non-null   bool
#  31  HomeTeam_Man City          1856 non-null   bool
#  32  HomeTeam_Man United        1856 non-null   bool
#  33  HomeTeam_Newcastle         1856 non-null   bool
#  34  HomeTeam_Norwich           1856 non-null   bool
#  35  HomeTeam_Nott'm Forest     1856 non-null   bool
#  36  HomeTeam_Sheffield United  1856 non-null   bool
#  37  HomeTeam_Southampton       1856 non-null   bool
#  38  HomeTeam_Stoke             1856 non-null   bool
#  39  HomeTeam_Swansea           1856 non-null   bool
#  40  HomeTeam_Tottenham         1856 non-null   bool
#  41  HomeTeam_Watford           1856 non-null   bool
#  42  HomeTeam_West Brom         1856 non-null   bool
#  43  HomeTeam_West Ham          1856 non-null   bool
#  44  HomeTeam_Wolves            1856 non-null   bool
#  45  AwayTeam_Arsenal           1856 non-null   bool
#  46  AwayTeam_Aston Villa       1856 non-null   bool
#  47  AwayTeam_Bournemouth       1856 non-null   bool
#  48  AwayTeam_Brentford         1856 non-null   bool
#  49  AwayTeam_Brighton          1856 non-null   bool
#  50  AwayTeam_Burnley           1856 non-null   bool
#  51  AwayTeam_Cardiff           1856 non-null   bool
#  52  AwayTeam_Chelsea           1856 non-null   bool
#  53  AwayTeam_Crystal Palace    1856 non-null   bool
#  54  AwayTeam_Everton           1856 non-null   bool
#  55  AwayTeam_Fulham            1856 non-null   bool
#  56  AwayTeam_Huddersfield      1856 non-null   bool
#  57  AwayTeam_Leeds             1856 non-null   bool
#  58  AwayTeam_Leicester         1856 non-null   bool
#  59  AwayTeam_Liverpool         1856 non-null   bool
#  60  AwayTeam_Man City          1856 non-null   bool
#  61  AwayTeam_Man United        1856 non-null   bool
#  62  AwayTeam_Newcastle         1856 non-null   bool
#  63  AwayTeam_Norwich           1856 non-null   bool
#  64  AwayTeam_Nott'm Forest     1856 non-null   bool
#  65  AwayTeam_Sheffield United  1856 non-null   bool
#  66  AwayTeam_Southampton       1856 non-null   bool
#  67  AwayTeam_Stoke             1856 non-null   bool
#  68  AwayTeam_Swansea           1856 non-null   bool
#  69  AwayTeam_Tottenham         1856 non-null   bool
#  70  AwayTeam_Watford           1856 non-null   bool
#  71  AwayTeam_West Brom         1856 non-null   bool
#  72  AwayTeam_West Ham          1856 non-null   bool
#  73  AwayTeam_Wolves            1856 non-null   bool
# dtypes: bool(58), float64(12), int32(4)
# memory usage: 322.6 KB

# %%
# Transformation simple: H -> 0, D -> 1, A -> 2 & Sélection de la variable cible
result_mapping = {'H': 0, 'D': 1, 'A': 2}
y_train = df_train_encoded['FT Result'].map(result_mapping)
y_test = df_test_encoded['FT Result'].map(result_mapping)


# Entraîner votre modèle
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Évaluer votre modèle
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Précision du modèle: {accuracy:.4f}")
# Out:
# Précision du modèle: 0.5736
